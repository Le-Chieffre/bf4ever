# %%
print("hello mom")
# Out:
# hello mom

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Generate sample data
np.random.seed(0)
data = {'X': np.random.rand(50), 'Y': np.random.rand(50)}

# Create a DataFrame
df = pd.DataFrame(data)
print(df.columns.values)
print(df)

# Create a scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(df['X'], df['Y'], c='blue', label='Data Points')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Scatter Plot Example')
plt.legend()
plt.show()
# Out:
# ['X' 'Y']
#            X         Y
# 0   0.548814  0.570197
# 1   0.715189  0.438602
# 2   0.602763  0.988374
# 3   0.544883  0.102045
# 4   0.423655  0.208877
# 5   0.645894  0.161310
# 6   0.437587  0.653108
# 7   0.891773  0.253292
# 8   0.963663  0.466311
# 9   0.383442  0.244426
# 10  0.791725  0.158970
# 11  0.528895  0.110375
# 12  0.568045  0.656330
# 13  0.925597  0.138183
# 14  0.071036  0.196582
# 15  0.087129  0.368725
# 16  0.020218  0.820993
# 17  0.832620  0.097101
# 18  0.778157  0.837945
# 19  0.870012  0.096098
# 20  0.978618  0.976459
# 21  0.799159  0.468651
# 22  0.461479  0.976761
# 23  0.780529  0.604846
# 24  0.118274  0.739264
# 25  0.639921  0.039188
# 26  0.143353  0.282807
# 27  0.944669  0.120197
# 28  0.521848  0.296140
# 29  0.414662  0.118728
# 30  0.264556  0.317983
# 31  0.774234  0.414263
# 32  0.456150  0.064147
# 33  0.568434  0.692472
# 34  0.018790  0.566601
# 35  0.617635  0.265389
# 36  0.612096  0.523248
# 37  0.616934  0.093941
# ...

# %%
import numpy as np
import pandas as pd

# https://rkr.statistikbank.dk/statbank5a/selectvarval/saveselections.asp?MainTable=BM011&PLanguage=0&TableStyle=&Buttons=&Pxsid=202310705341433772641BM011&TC=0&UseDots=True&ST=ST
solgte_boliger = pd.read_excel("./202310715914433780985BM010 (1).xlsx")
solgte_boliger.dropna()
solgte_boliger.drop(1, axis=0, inplace=True)

# print(solgte_boliger.columns.values)

for label, content in solgte_boliger.items():
    print(f"{label} : {content}")

unit = "kr. pr. m2"
# Out:
# Ejendomspriser på boligmarkedet efter ejendomskategori, område, priser på realiserede handler og tid : 0    Enhed: Kr. pr. m2
# 2        Ejerlejlighed
# 3                  NaN
# 4                  NaN
# Name: Ejendomspriser på boligmarkedet efter ejendomskategori, område, priser på realiserede handler og tid, dtype: object
# Unnamed: 1 : 0              NaN
# 2    Frederiksberg
# 3              NaN
# 4              NaN
# Name: Unnamed: 1, dtype: object
# Unnamed: 2 : 0                       NaN
# 2         Første udbudspris
# 3           Nedtagningspris
# 4    Realiseret handelspris
# Name: Unnamed: 2, dtype: object
# Unnamed: 3 : 0     NaN
# 2      ..
# 3      ..
# 4    6529
# Name: Unnamed: 3, dtype: object
# Unnamed: 4 : 0     NaN
# 2      ..
# 3      ..
# 4    6520
# Name: Unnamed: 4, dtype: object
# Unnamed: 5 : 0     NaN
# 2      ..
# 3      ..
# 4    6386
# Name: Unnamed: 5, dtype: object
# Unnamed: 6 : 0     NaN
# 2      ..
# 3      ..
# 4    6512
# ...
